# %% [markdown]
# ### Responder às seguintes perguntas:
#
#
#     a. Qual o tamanho desse dataset?
#     b. Qual a média da coluna windspeed?
#     c. Qual a média da coluna temp?
#     d. Quantos registros existem para o ano de 2011?
#     e. Quantos registros existem para o ano de 2012?
#     f. Quantas locações de bicicletas foram efetuadas em 2011?
#     g. Quantas locações de bicicletas foram efetuadas em 2012?
#     h. Qual estação do ano contém a maior média de locações de bicicletas?
#     i. Qual estação do ano contém a menor média de locações de bicicletas?
#     j. Qual horário do dia contém a maior média de locações de bicicletas?
#     k. Qual horário do dia contém a menor média de locações de bicicletas?
#     l. Que dia da semana contém a maior média de locações de bicicletas?
#     m. Que dia da semana contém a menor média de locações de bicicletas?
#     n. Às quartas-feiras (weekday = 3), qual o horário do dia que contém a maior média de locações de bicicletas?
#     o. Aos sábados (weekday = 6), qual o horário do dia que contém a maior média de locações de bicicletas?
#
# ### Descrição das colunas
#
#     − rec_id: índice do registro de locação;
#     − datetime: data;
#     − season: estação do ano (1: inverno, 2: primavera, 3: verão, 4: outono). Relativo ao hemisfério norte;
#     − year: ano (0: 2011, 1:2012); − month: mês (1 a 12);
#     − hour: hora do dia (0 a 23); − is_holiday: booleano indicando feriado; − weekday: dia da semana (0: domingo, 1: segunda-feira, …, 6: sábado);
#     − is_workingday: booleano indicando dia útil;
#     − weather_condition: (1: limpo, 2: nublado, 3: chuva leve, 4: chuva forte);
#     − temp: Temperatura escalada entre 0 e 1. Valor original em graus Celsius: -8 a 39;
#     − atemp: Sensação térmica escalada entre 0 e 1. Valor original em graus Celsius: -16 a 50;
#     − humidity: Humidade relativa (0 a 1); − windspeed: Velocidade do vento escalada entre 0 e 1 (máximo original: 67);
#     − casual: número de locações para usuários casuais;
#     − registered: número de locações para usuários registrados;
#     − total_count: contador total de aluguéis (casual+registered).

# %%
import numpy as np
import pandas as pd


df = pd.read_csv("https://pycourse.s3.amazonaws.com/bike-sharing.csv")

# %%
df.tail()
# Out:
#          datetime  rec_id  season  year  month  hour  is_holiday  weekday  \
# 17374  2012-12-31   17375       1     1     12    19           0        1
# 17375  2012-12-31   17376       1     1     12    20           0        1
# 17376  2012-12-31   17377       1     1     12    21           0        1
# 17377  2012-12-31   17378       1     1     12    22           0        1
# 17378  2012-12-31   17379       1     1     12    23           0        1
#
#        is_workingday  weather_condition  temp   atemp  humidity  windspeed  \
# 17374              1                  2  0.26  0.2576      0.60     0.1642
# 17375              1                  2  0.26  0.2576      0.60     0.1642
# 17376              1                  1  0.26  0.2576      0.60     0.1642
# 17377              1                  1  0.26  0.2727      0.56     0.1343
# 17378              1                  1  0.26  0.2727      0.65     0.1343
#
#        casual  registered  total_count
# ...

# %%
print("Respostas:")

# Resposta a

print("Tamanho: ", df.shape)

# Resposta b

print("Média windspeed: ", df["windspeed"].mean())

# Resposta c

print("Média temperatura: ", df["temp"].mean())

# Resposta d

print("Qtd de registros ano 2011: ", df["year"].value_counts()[0])

# Resposta e

print("Qtd de registros ano 2012: ", df["year"].value_counts()[1])

# Resposta f

print("Locações feitas em 2011: ", df[df["year"] == 0]["total_count"].sum())

# Resposta g

print("Locações feitas em 2012: ", df[df["year"] == 1]["total_count"].sum())

# Resposta h

print("Estação com maior média de locações: ", df.groupby("season")["total_count"].mean().idxmax())

# Resposta i

print("Estação com menor média de locações: ", df.groupby("season")["total_count"].mean().idxmin())

# Resposta j

print("Horario com maior média de locações: ", df.groupby("hour")["total_count"].mean().idxmax())

# Resposta k

print("Horario com menor média de locações: ", df.groupby("hour")["total_count"].mean().idxmin())

# Resposta l

print("Dia da semana com maior média de locações: ", df.groupby("weekday")["total_count"].mean().idxmax())

# Resposta m

print("Dia da semana com menor média de locações: ", df.groupby("weekday")["total_count"].mean().idxmin())

# Resposta n

print("Durante as Quartas-feiras qual o horário com maiores alocações: ", df[df["weekday"] == 3].groupby("hour")["total_count"].mean().idxmax())

# Resposta o

print("Durante as Sábados qual o horário com maiores alocações: ", df[df["weekday"] == 6].groupby("hour")["total_count"].mean().idxmax())
# Out:
# Respostas:
# Tamanho:  (17379, 17)
# Média windspeed:  0.19009760630646177
# Média temperatura:  0.4969871684216583
# Qtd de registros ano 2011:  8645
# Qtd de registros ano 2012:  8734
# Locações feitas em 2011:  1243103
# Locações feitas em 2012:  2049576
# Estação com maior média de locações:  3
# Estação com menor média de locações:  1
# Horario com maior média de locações:  17
# Horario com menor média de locações:  4
# Dia da semana com maior média de locações:  4
# Dia da semana com menor média de locações:  0
# Durante as Quartas-feiras qual o horário com maiores alocações:  17
# Durante as Sábados qual o horário com maiores alocações:  13
